# %% [markdown]
# # Model-Based Reinforcement Learning

# %% [markdown]
# This notebook is written by Mathias Rose Bjare (muthissar@gmail.com) and  answears Deep RL Assignment 4, http://rail.eecs.berkeley.edu/deeprlcourse/static/homeworks/hw4.pdf.
# The code base for this file can be found at https://github.com/muthissar/homework.

# %%
# %load_ext autoreload
# %autoreload 2
#%matplotlib notebook
import pickle
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
from IPython.display import Image
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Problem 1
# a) The following image gives the best result for the problem.

# %%
Image(filename='data/HalfCheetah_q1_exp/prediction_005.jpg')

# %% [markdown]
# b) For state dimension 17 the predictions seem to be most inaccurate. From inspecting the different images it is seen that there is a lot variation in this state dimension. For instance consider ther images:

# %%
Image(filename='data/HalfCheetah_q1_exp/prediction_009.jpg')

# %%
Image(filename='data/HalfCheetah_q1_exp/prediction_007.jpg')

# %% [markdown]
# ### Problem 2
# a) The statistics for the random policy is given by

# %%
df = pd.read_csv('data/HalfCheetah_q2_exp/log.csv')
df.iloc[0]
# Out:
# Unnamed: 0             0.000000
# ReturnAvg           -152.554540
# ReturnStd             27.798994
# ReturnMin           -202.932991
# ReturnMax           -108.343106
# TrainingLossStart           NaN
# TrainingLossFinal           NaN
# Name: 0, dtype: float64

# %% [markdown]
# For the trained model the statistic is

# %%
df.iloc[1]
# Out:
# Unnamed: 0            1.000000
# ReturnAvg           -11.421912
# ReturnStd            28.376848
# ReturnMin           -70.436416
# ReturnMax            17.430051
# TrainingLossStart     1.044342
# TrainingLossFinal     0.028411
# Name: 1, dtype: float64

# %% [markdown]
# Which is reasonalby close to an average of 0.

# %% [markdown]
# ### Problem 3a
# a) The problems is plotted

# %%
Image(filename='plots/HalfCheetah_q3_default.jpg')

# %% [markdown]
# Which is close to the 300 expected.

# %% [markdown]
# ### Problem 3b
# a) Variying the horizon

# %%
Image(filename='plots/HalfCheetah_q3_mpc_horizon.jpg')

# %% [markdown]
# It is seen that it indeed improve performance to have a longer horizon. However the performance gain from going from 10 to 15 is more significant than from 15, 20. Indicating that there is a balance point where planning further ahead might not help us improve performance.
#
# b) When variying the number of randomly action sequences

# %%
Image(filename='plots/HalfCheetah_q3_actions.jpg')

# %% [markdown]
# It does indeed improve to vary the number. However the gain going from 4096 to 16384 is not as high than from 128 to 4096.
#
# c) varying the number of layers

# %%
Image(filename='plots/HalfCheetah_q3_nn_layers.jpg')

# %% [markdown]
# It is seen that it doesn't help to much to change the number of layers. This also coincides with our intuition that the model based policies are usually less expressive, and as such the added layers doesn't improve on the performance.
